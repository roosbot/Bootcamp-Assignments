# %% [markdown]
# # Subsetting and Descriptive Stats
#
# ## Before your start:
#    - Remember that you just need to do one of the challenges.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in IronHack's database.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly: enjoy the process!
#
# #### Import all the necessary libraries here:

# %%
# import libraries here
import pandas as pd

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 1
# #### In this challenge we will use the `Temp_States`  dataset.
#
# #### First import it into a dataframe called `temp`.

# %%
# your code here

# %% [markdown]
# #### Print `temp`.

# %%
# your code here

# %% [markdown]
# #### Explore the data types of the *temp* dataframe. What types of data do we have? Comment your result.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### Select the rows where state is New York.

# %%
# your code here

# %% [markdown]
# #### What is the average temperature of cities in New York?

# %%
# your code here

# %% [markdown]
# #### Which states and cities have a temperature above 15 degrees Celsius?

# %%
# your code here

# %% [markdown]
# #### Now, return only the cities that have a temperature above 15 degrees Celsius.

# %%
# your code here

# %% [markdown]
# #### Which cities have a temperature above 15 degrees Celcius and below 20 degrees Celsius?
#
# **Hint**: First, write the condition. Then, select the rows.

# %%
# your code here

# %% [markdown]
# #### Find the mean and standard deviation of the temperature of each state.

# %%
# your code here

# %% [markdown]
# # [ONLY ONE MANDATORY]  Challenge 2

# %% [markdown]
# #### Load the `employees` dataset into a dataframe. Call the dataframe `employees`.

# %%
# your code here

# %% [markdown]
# #### Explore the data types of the `employees` dataframe. Comment your results.

# %%
# your code here

# %%
"""
your comments here
"""

# %% [markdown]
# #### What's the average salary in this company?

# %%
# your code here

# %% [markdown]
# #### What's the highest salary?

# %%
# your code here

# %% [markdown]
# #### What's the lowest salary?

# %%
# your code here

# %% [markdown]
# #### Who are the employees with the lowest salary?

# %%
# your code here

# %% [markdown]
# #### Find all the information about an employee called David.

# %%
# your code here

# %% [markdown]
# #### Could you return only David's salary?

# %%
# your code here

# %% [markdown]
# #### Print all the rows where job title is associate.

# %%
# your code here

# %% [markdown]
# #### Print the first 3 rows of your dataframe.
# **Tip**: There are 2 ways to do it. Do it both ways.

# %%
# Method 1
# your code here

# %%
# Method 2
# your code here

# %% [markdown]
# #### Find the employees whose title is associate and whose salary is above 55.

# %%
# your code here

# %% [markdown]
# #### Group the employees by number of years of employment. What are the average salaries in each group?

# %%
# your code here

# %% [markdown]
# ####  What is the average salary per title?

# %%
# your code here

# %% [markdown]
# ####  Find the salary quartiles.

# %%
# your code here

# %% [markdown]
# #### Is the mean salary different per gender?

# %%
# your code here

# %% [markdown]
# #### Find the minimum, mean and maximum of all numeric columns for each company department.

# %%
# your code here

# %% [markdown]
# #### Bonus Question:  for each department, compute the difference between the maximum and the minimum salary.
# **Hint**: try using `agg` or `apply` combined with `lambda` functions.

# %%
# your code here

# %% [markdown]
# # [ONLY ONE MANDATORY] Challenge 3
# #### Open the `Orders` dataset. Name your dataset `orders`.

# %%
# your code here

# Two plots!

orders = pd.read_csv("Orders.csv")
orders = orders.drop("Unnamed: 0", axis=1)
orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 0          536365    85123A  2010     12    3     8
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 397919     581587     22613  2011     12    5    12
# 397920     581587     22899  2011     12    5    12
# 397921     581587     23254  2011     12    5    12
# 397922     581587     23255  2011     12    5    12
# 397923     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# #### Explore your dataset by looking at the data types and summary statistics. Comment your results.

# %%
# your code here
print(orders.dtypes,"\n")
print(orders.info())
orders.describe()
# Out:
# InvoiceNo         int64
# StockCode        object
# year              int64
# month             int64
# day               int64
# hour              int64
# Description      object
# Quantity          int64
# InvoiceDate      object
# UnitPrice       float64
# CustomerID        int64
# Country          object
# amount_spent    float64
# dtype: object
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397924 entries, 0 to 397923
# Data columns (total 13 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   InvoiceNo     397924 non-null  int64
#  1   StockCode     397924 non-null  object
#  2   year          397924 non-null  int64
#  3   month         397924 non-null  int64
#  4   day           397924 non-null  int64
#  5   hour          397924 non-null  int64
#  6   Description   397924 non-null  object
#  7   Quantity      397924 non-null  int64
#  8   InvoiceDate   397924 non-null  object
# ...

# %%
"""
There are a lot of orders (397.924). 
The orders are ranging from 2010-2011
The orders only occured between 6am till 20am
The quantity ordered ranges from 1 to 80995! Average of 13
The unit price ranges from 0 tot 18287. Average of 3.
The zero for unit price doesn't make sense to me.
The amount spent can be 0, that doesn't make sense.
The max amount spent is 168469. Average is 22
"""

# %% [markdown]
# ####  What is the average purchase price?

# %%
# your code here

# Do you mean item price or average order value?

## average item price
overview = orders.describe().transpose()
avg_item_price = overview["mean"][8]
print("The average item price is", int(avg_item_price))

## create customer dataframe
customers = orders.groupby(["CustomerID","Country"],as_index=False).agg({"amount_spent":"sum","Quantity":"sum","InvoiceNo":"count"})
customers.columns=["CustomerID","Country","Ordervalue","Quantity","Orders"]
customers["Avg_ordervalue"] = customers["Ordervalue"]/customers["Orders"]

## average order value
overview2 = customers.describe().transpose()
avg_ordervalue = overview2["mean"][4]
print("The average order value is", int(avg_ordervalue))
# Out:
# The average item price is 22
# The average order value is 68

# %%
customers
# Out:
#       CustomerID         Country  Ordervalue  Quantity  Orders  Avg_ordervalue
# 0          12346  United Kingdom    77183.60     74215       1    77183.600000
# 1          12347         Iceland     4310.00      2458     182       23.681319
# 2          12348         Finland     1797.24      2341      31       57.975484
# 3          12349           Italy     1757.55       631      73       24.076027
# 4          12350          Norway      334.40       197      17       19.670588
# ...          ...             ...         ...       ...     ...             ...
# 4342       18280  United Kingdom      180.60        45      10       18.060000
# 4343       18281  United Kingdom       80.82        54       7       11.545714
# 4344       18282  United Kingdom      178.05       103      12       14.837500
# 4345       18283  United Kingdom     2094.88      1397     756        2.771005
# 4346       18287  United Kingdom     1837.28      1586      70       26.246857
#
# [4347 rows x 6 columns]

# %%
overview
# Out:
#                  count           mean           std       min        25%  \
# InvoiceNo     397924.0  560617.126645  13106.167695  536365.0  549234.00
# year          397924.0    2010.934259      0.247829    2010.0    2011.00
# month         397924.0       7.612537      3.416527       1.0       5.00
# day           397924.0       3.614555      1.928274       1.0       2.00
# hour          397924.0      12.728247      2.273535       6.0      11.00
# Quantity      397924.0      13.021823    180.420210       1.0       2.00
# UnitPrice     397924.0       3.116174     22.096788       0.0       1.25
# CustomerID    397924.0   15294.315171   1713.169877   12346.0   13969.00
# amount_spent  397924.0      22.394749    309.055588       0.0       4.68
#
#                     50%        75%        max
# InvoiceNo     561893.00  572090.00  581587.00
# year            2011.00    2011.00    2011.00
# month              8.00      11.00      12.00
# day                3.00       5.00       7.00
# ...

# %%
overview2
# Out:
#                  count          mean          std      min           25%  \
# CustomerID      4339.0  15299.936852  1721.889758  12346.0  13812.500000
# Ordervalue      4339.0   2053.793018  8988.248381      0.0    307.245000
# Quantity        4339.0   1194.214335  5055.603049      1.0    160.000000
# Orders          4339.0     91.708689   228.792852      1.0     17.000000
# Avg_ordervalue  4339.0     68.303655  1467.745469      0.0     12.353054
#
#                          50%          75%        max
# CustomerID      15299.000000  16778.50000   18287.00
# Ordervalue        674.450000   1661.64000  280206.02
# Quantity          379.000000    993.00000  197491.00
# Orders             41.000000    100.00000    7847.00
# Avg_ordervalue     17.716923     24.84841   77183.60

# %% [markdown]
# #### What are the highest and lowest purchase prices?

# %%
## highest and lowest item price
min_purchase_price = overview["min"][8]
max_purchase_price = overview["max"][8]
print("The highest item price is", int(max_purchase_price))
print("The lowest item price is", int(min_purchase_price))

## highest and lowest order value
min_ordervalue = overview2["min"][1]
max_ordervalue = overview2["max"][1]
print("The highest order value is", int(max_ordervalue))
print("The lowest order value is", int(min_ordervalue))
# Out:
# The highest item price is 168469
# The lowest item price is 0
# The highest order value is 280206
# The lowest order value is 0

# %% [markdown]
# #### Select all the customers from Spain.
# **Hint**: Remember that you are not asked to find orders from Spain but customers. A customer might have more than one order associated.

# %%
# your code here
orders_spain = orders[(orders["Country"] == "Spain")]
customers_spain = orders_spain.groupby("CustomerID",as_index=False).agg({"amount_spent":"sum","Quantity":"sum","InvoiceNo":"count"})
customers_spain

# %%
# your code here
customers_spain = customers[(customers["Country"] == "Spain")]
customers_spain
# Out:
#       CustomerID Country  Ordervalue  Quantity  Orders  Avg_ordervalue
# 7          12354   Spain     1079.40       530      58       18.610345
# 59         12417   Spain      436.30       267      23       18.969565
# 62         12421   Spain      807.04       484      45       17.934222
# 84         12442   Spain      172.06       182      12       14.338333
# 86         12445   Spain      133.40        62       4       33.350000
# 89         12448   Spain      449.45       243      22       20.429545
# 91         12450   Spain      197.88       128       8       24.735000
# 95         12454   Spain     3528.34      1006      15      235.222667
# 97         12455   Spain      767.96       566      48       15.999167
# 103        12462   Spain     1189.59       536      62       19.186935
# 120        12484   Spain     4541.72      2191     346       13.126358
# 132        12502   Spain     3723.87       820     147       25.332449
# ...

# %% [markdown]
# #### How many customers do we have in Spain?

# %%
# your code here
print("There are",customers_spain.shape[0],"customers in Spain")
# Out:
# There are 30 customers in Spain

# %% [markdown]
# #### Select all the customers who have bought more than 50 items.
# **Hint**: Remember that you are not asked to find orders with more than 50 items but customers who bought more than 50 items. A customer with two orders of 30 items each should appear in the selection.

# %%
# your code here
select = customers_spain[(customers_spain["Orders"] > 50)]
select
# Out:
#       CustomerID Country  Ordervalue  Quantity  Orders  Avg_ordervalue
# 7          12354   Spain     1079.40       530      58       18.610345
# 103        12462   Spain     1189.59       536      62       19.186935
# 120        12484   Spain     4541.72      2191     346       13.126358
# 132        12502   Spain     3723.87       820     147       25.332449
# 162        12539   Spain     5568.35      2067     273       20.396886
# 163        12540   Spain    13400.24      6685     478       28.033975
# 164        12541   Spain      981.18       680      52       18.868846
# 167        12546   Spain     1161.50       633      69       16.833333
# 170        12550   Spain      964.83       569      57       16.926842
# 174        12556   Spain      603.71       358     121        4.989339
# 210        12597   Spain     3811.22      2236     206       18.501068
# 3492       17097   Spain      954.42       459     211        4.523318

# %% [markdown]
# #### Select orders from Spain that include more than 50 items.

# %%
# your code here
select = customers_spain[(customers_spain["Quantity"] > 50)]
select
# Out:
#       CustomerID Country  Ordervalue  Quantity  Orders  Avg_ordervalue
# 7          12354   Spain     1079.40       530      58       18.610345
# 59         12417   Spain      436.30       267      23       18.969565
# 62         12421   Spain      807.04       484      45       17.934222
# 84         12442   Spain      172.06       182      12       14.338333
# 86         12445   Spain      133.40        62       4       33.350000
# 89         12448   Spain      449.45       243      22       20.429545
# 91         12450   Spain      197.88       128       8       24.735000
# 95         12454   Spain     3528.34      1006      15      235.222667
# 97         12455   Spain      767.96       566      48       15.999167
# 103        12462   Spain     1189.59       536      62       19.186935
# 120        12484   Spain     4541.72      2191     346       13.126358
# 132        12502   Spain     3723.87       820     147       25.332449
# ...

# %% [markdown]
# #### Select all free orders.

# %%
# your code here
select = orders[(orders["amount_spent"] == 0)]
select
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 6914       537197     22841  2010     12    7    14
# 22539      539263     22580  2010     12    4    14
# 25379      539722     22423  2010     12    2    13
# 29080      540372     22090  2011      1    4    16
# 29082      540372     22553  2011      1    4    16
# 34494      541109     22168  2011      1    4    15
# 53788      543599    84535B  2011      2    4    13
# 85671      547417     22062  2011      3    3    10
# 92875      548318     22055  2011      3    3    12
# 97430      548871     22162  2011      4    1    14
# 107192     550188     22636  2011      4    4    18
# 128641     553000     47566  2011      5    4    15
# 137127     554037     22619  2011      5    5    14
# 194648     561284     22167  2011      7    2    12
# 197173     561669     22960  2011      7    4    17
# 199711     561916         M  2011      8    1    11
# 208950     562973     23157  2011      8    4    11
# ...

# %% [markdown]
# #### Select all orders whose description starts with `lunch bag`.
# **Hint**: use string functions.

# %%
# your code here
lunch_bag = orders.loc[(orders["Description"].str.startswith("lunch bag"))]
lunch_bag
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 93         536378     20725  2010     12    3     9
# 172        536385     22662  2010     12    3     9
# 354        536401     22662  2010     12    3    11
# 359        536401     20725  2010     12    3    11
# 360        536401     22382  2010     12    3    11
# ...           ...       ...   ...    ...  ...   ...
# 397465     581486     23207  2011     12    5     9
# 397713     581538     20727  2011     12    5    11
# 397714     581538     20725  2011     12    5    11
# 397877     581581     23681  2011     12    5    12
# 397880     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 93          lunch bag red retrospot        10  2010-12-01 09:37:00       1.65
# 172     lunch bag dolly girl design        10  2010-12-01 09:56:00       1.65
# 354     lunch bag dolly girl design         1  2010-12-01 11:21:00       1.65
# ...

# %% [markdown]
# #### Select all `lunch bag` orders made in 2011.

# %%
# your code here
select = lunch_bag[(lunch_bag["year"] == 2011)]
select
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 26340      540015     20725  2011      1    2    11
# 26341      540015     20726  2011      1    2    11
# 26512      540023     22382  2011      1    2    12
# 26513      540023     20726  2011      1    2    12
# 26860      540098     22384  2011      1    2    15
# ...           ...       ...   ...    ...  ...   ...
# 397465     581486     23207  2011     12    5     9
# 397713     581538     20727  2011     12    5    11
# 397714     581538     20725  2011     12    5    11
# 397877     581581     23681  2011     12    5    12
# 397880     581583     20725  2011     12    5    12
#
#                         Description  Quantity          InvoiceDate  UnitPrice  \
# 26340       lunch bag red retrospot        10  2011-01-04 11:40:00       1.65
# 26341            lunch bag woodland        10  2011-01-04 11:40:00       1.65
# 26512    lunch bag spaceboy design          2  2011-01-04 12:58:00       1.65
# ...

# %% [markdown]
# #### Show the frequency distribution of the amount spent in Spain.

# %%
# your code here
orders_spain = orders[(orders["Country"] == "Spain")]
orders_spain["amount_spent"].hist()

# %%
# your code here
customers_spain["Ordervalue"].hist()

# %% [markdown]
# #### Select all orders made in the month of August.

# %%
# your code here
august = orders[(orders['month'] == 8)]
august
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 199475     561904     22075  2011      8    1     8
# 199476     561904    85049E  2011      8    1     8
# 199477     561905     21385  2011      8    1     9
# 199478     561905    84970L  2011      8    1     9
# 199479     561905    84970S  2011      8    1     9
# ...           ...       ...   ...    ...  ...   ...
# 226483     565067     22644  2011      8    3    17
# 226484     565067     22645  2011      8    3    17
# 226485     565067     22637  2011      8    3    17
# 226486     565067     22646  2011      8    3    17
# 226487     565067     22741  2011      8    3    17
#
#                                 Description  Quantity          InvoiceDate  \
# 199475         6 ribbons elegant christmas         96  2011-08-01 08:30:00
# 199476            scandinavian reds ribbons       156  2011-08-01 08:30:00
# 199477      ivory hanging decoration  heart        24  2011-08-01 09:31:00
# ...

# %% [markdown]
# #### Find the number of orders made by each country in the month of August.
# **Hint**: Use value_counts().

# %%
# your code here
orders_country = august.groupby("Country",as_index=False).agg({"InvoiceNo":"count","amount_spent":"sum"})
orders_country
# Out:
#             Country  InvoiceNo  amount_spent
# 0         Australia        107      22489.20
# 1           Austria         88       1516.08
# 2           Belgium        194       3554.02
# 3            Canada          5         51.56
# 4   Channel Islands        140       4896.78
# 5           Denmark         16        213.15
# 6              EIRE        593      16967.38
# 7           Finland         61       1376.50
# 8            France        569      13810.96
# 9           Germany        795      19220.77
# 10          Iceland         22        584.91
# 11           Israel        171       4873.81
# 12            Italy         95       1990.95
# 13            Malta         55       1119.00
# 14      Netherlands        280      40327.81
# 15           Norway         77       2025.81
# 16           Poland         17        401.80
# 17         Portugal         41       1221.40
# 18            Spain        252       3346.91
# 19           Sweden         40       1400.86
# ...

# %% [markdown]
# #### What's the  average amount of money spent by country?

# %%
# your code here
orders_country = august.groupby("Country",as_index=False).agg({"InvoiceNo":"count","amount_spent":"mean"})
orders_country
# Out:
#             Country  InvoiceNo  amount_spent
# 0         Australia        107    210.179439
# 1           Austria         88     17.228182
# 2           Belgium        194     18.319691
# 3            Canada          5     10.312000
# 4   Channel Islands        140     34.977000
# 5           Denmark         16     13.321875
# 6              EIRE        593     28.612782
# 7           Finland         61     22.565574
# 8            France        569     24.272337
# 9           Germany        795     24.177069
# 10          Iceland         22     26.586818
# 11           Israel        171     28.501813
# 12            Italy         95     20.957368
# 13            Malta         55     20.345455
# 14      Netherlands        280    144.027893
# 15           Norway         77     26.309221
# 16           Poland         17     23.635294
# 17         Portugal         41     29.790244
# 18            Spain        252     13.281389
# 19           Sweden         40     35.021500
# ...

# %% [markdown]
# #### What's the most expensive item?

# %%
# your code here
overview = orders.describe().transpose()
max_price = overview['max'][6]
print("The most expensive item is", max_price)
# Out:
# The most expensive item is 8142.75

# %% [markdown]
# #### What is the average amount spent per year?

# %%
# your code here
orders_year = orders.groupby("year",as_index=False).agg({"amount_spent":"mean"})
orders_year
# Out:
#    year  amount_spent
# 0  2010     21.892733
# 1  2011     22.430074
