# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import pandas as pd
import numpy as np
import re

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from Ironhack's database:
# * db: `admissions predict`
# * table: `admissions predict`

# %%
# your code here
admissions = pd.read_csv("./Admission_Predict.csv")
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Chance of Admit
# ...

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
# your code here
# admissions.columns
admissions.columns = admissions.columns.str.strip()
admissions.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# your code here

admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.76
# 2         1             0.72
# 3         1             0.80
# 4         0             0.65

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# your code here
admissions.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# your code here
admissions = admissions.set_index("Serial No.", drop=False)
admissions.head()

## used as a reference: https://appdividend.com/2019/01/26/pandas-set-index-example-python-set_index-tutorial/
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        324          107                  4  4.0  4.5
# 3                    3        316          104                  3  3.0  3.5
# 4                    4        322          110                  3  3.5  2.5
# 5                    5        314          103                  2  2.0  3.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.87         1             0.76
# 3           8.00         1             0.72
# 4           8.67         1             0.80
# 5           8.21         0             0.65

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
GRE_Score = admissions["GRE Score"]
GRE_Score_unique = GRE_Score.is_unique
print("GRE Score is unique:", GRE_Score_unique)

CGPA = admissions["CGPA"]
CGPA_unique = CGPA.is_unique
print("CGPA_unique is unique:", CGPA_unique)
# Out:
# GRE Score is unique: False
# CGPA_unique is unique: False

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %%
# # your code here
# admissions = admissions.set_index(["GRE Score","CGPA"], inplace=True, drop=False)
# ## Used as a reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html

# %%
admissions.head()
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        324          107                  4  4.0  4.5
# 3                    3        316          104                  3  3.0  3.5
# 4                    4        322          110                  3  3.5  2.5
# 5                    5        314          103                  2  2.0  3.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.87         1             0.76
# 3           8.00         1             0.72
# 4           8.67         1             0.80
# 5           8.21         0             0.65

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# your code here
admissions.reset_index(inplace=True)
admission.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-abebcf575010> in <module>
#       1 # your code here
# ----> 2 admissions.reset_index(inplace=True)
#       3 admission.head()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill)
#    4602                 # to ndarray and maybe infer different dtype
#    4603                 level_values = _maybe_casted_values(lev, lab)
# -> 4604                 new_obj.insert(0, name, level_values)
#    4605
#    4606         new_obj.index = new_index
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3494         self._ensure_valid_index(value)
#    3495         value = self._sanitize_column(column, value, broadcast=False)
# ...

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# your code here
admissions[(admissions["CGPA"] > 9) & (admissions["Research"] == 1)]
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 6                    6        330          115                  5  4.5  3.0
# 13                  13        328          112                  4  4.0  4.5
# 23                  23        328          116                  5  5.0  5.0
# 24                  24        334          119                  5  5.0  4.5
# ...                ...        ...          ...                ...  ...  ...
# 395                395        329          111                  4  4.5  4.0
# 396                396        324          110                  3  3.5  3.5
# 397                397        325          107                  3  3.0  3.5
# 398                398        330          116                  4  5.0  4.5
# 400                400        333          117                  4  5.0  4.0
#
#             CGPA  Research  Chance of Admit
# ...

# %%
admissions.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Chance of Admit'],
#       dtype='object')

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# your code here
selection = admissions[(admissions["CGPA"] > 9) & (admissions["SOP"] < 3.5)]
selection["Chance of Admit"].mean()
# Out:
# 0.8019999999999999

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    """
    This function takes a column from a dataframe 
    and returns a standardized column by subtracting the column's mean
    and dividing by the column's standard deviation.
    """
    
    # your code here
    for student in col:
        return (student - np.mean(col)) / np.std(col)

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# your code here
admissions["CGPA_std"] = standardize(admissions["CGPA"])
admissions["GRE_std"] = standardize(admissions["GRE Score"])
admissions["LOR_std"] = standardize(admissions["LOR"])
admissions

# Used as a reference: https://github.com/pandas-dev/pandas/issues/18028
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        324          107                  4  4.0  4.5
# 3                    3        316          104                  3  3.0  3.5
# 4                    4        322          110                  3  3.5  2.5
# 5                    5        314          103                  2  2.0  3.0
# ...                ...        ...          ...                ...  ...  ...
# 396                396        324          110                  3  3.5  3.5
# 397                397        325          107                  3  3.0  3.5
# 398                398        330          116                  4  5.0  4.5
# 399                399        312          103                  3  3.5  4.0
# 400                400        333          117                  4  5.0  4.0
#
# ...

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Libraries
from random import choices

# %%
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])
decision_choice
# Out:
# ['LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'GRE_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'CGPA_std',
#  'GRE_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'CGPA_std',
#  'LOR_std',
#  'GRE_std',
#  'LOR_std',
#  'LOR_std',
#  'LOR_std',
#  'CGPA_std',
# ...

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# your code here
deciding_column = pd.Series(decision_choice, name = "deciding_column")
admissions = pd.concat([admissions, deciding_column], axis = 1)

admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           NaN        NaN          NaN                NaN  NaN  NaN   NaN
# 1           1.0      337.0        118.0                4.0  4.5  4.5  9.65
# 2           2.0      324.0        107.0                4.0  4.0  4.5  8.87
# 3           3.0      316.0        104.0                3.0  3.0  3.5  8.00
# 4           4.0      322.0        110.0                3.0  3.5  2.5  8.67
# ..          ...        ...          ...                ...  ...  ...   ...
# 396       396.0      324.0        110.0                3.0  3.5  3.5  9.04
# 397       397.0      325.0        107.0                3.0  3.0  3.5  9.11
# 398       398.0      330.0        116.0                4.0  5.0  4.5  9.45
# 399       399.0      312.0        103.0                3.0  3.5  4.0  8.78
# 400       400.0      333.0        117.0                4.0  5.0  4.0  9.66
#
# ...

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# your code here
# admissions["decision"] = admissions[(admissions[deciding_column])]

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# your code here

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# your code here
admissions = pd.read_csv("./Admission_Predict.csv")
admissions.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
# your code here
admissions.columns = admissions.columns.str.replace(" ", "_") # Add underscore
admissions.columns = admissions.columns.str.replace(r"[^a-zA-Z\d\_]+", "") # Add underscore
admissions.columns = map(str.lower, admissions.columns)  # noncharacter symbols 
admissions.columns
# Out:
# Index(['serial_no', 'gre_score', 'toefl_score', 'university_rating', 'sop',
#        'lor_', 'cgpa', 'research', 'chance_of_admit_'],
#       dtype='object')

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# your code here

# If university rating >= 4 then +10 in gre_score

# admissions.loc[admissions["university_rating"] >= 4, "gre_score"] =+ 10

# for student in admissions:
#     if admissions["university_rating"] >= 4:
#         admissions["gre_score"] =+ 10
#     else:
#         print("something went wrong")

# %%
# Split columns into bins
labels = ["Low","Medium","High", "Very High"]
admissions["adjusted_gre"] = pd.cut(admissions["gre_score"], 4, labels = labels)
admissions

# %%
admissions

# %%
admissions
