# %% [markdown]
# # Explore correlations
# Using the Canadian Disaster Database (CDD.csv, can be found on the share directory), you will explore the correlations between the numerical columns in the dataset. More info on the dataset can be found at https://www.kaggle.com/criticalhits/canadian-disaster-database#CDD.csv
#
# 1. Print the correlation matrix
#
# 2. Print a heat map of this correlation matrix (hint: use seaborn.heatmap())
#
# 3. Find 3 pairs of columns, one pair that is highly positively correlated, one for which the correlation is almost zero and one pair that is negatively correlated. In each case write down an explanation why we see this correlation
#
# 4. Look up the pairplot function in Seaborn. Use it to plot the pairwise relations between the six columns you selected. Does what you see confirm your ideas? Describe in a comment.

# %%
# import libraries
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
# 1. Print the correlation matrix
cdd = pd.read_csv("CDD.csv", sep="\t")
cdd
# Out:
#      EVENT CATEGORY EVENT GROUP                 EVENT SUBGROUP  \
# 0          Disaster     Natural  Meteorological - Hydrological
# 1          Disaster     Natural  Meteorological - Hydrological
# 2          Disaster     Natural  Meteorological - Hydrological
# 3          Disaster     Natural                     Biological
# 4          Incident  Technology            Hazardous Chemicals
# ...             ...         ...                            ...
# 1084       Disaster     Natural  Meteorological - Hydrological
# 1085       Incident  Technology                      Explosion
# 1086       Incident  Technology                      Explosion
# 1087       Incident  Technology         Infrastructure failure
# 1088       Incident  Technology                           Fire
#
#                        EVENT TYPE                                 PLACE  \
# 0     Storm - Unspecified / Other                   Christmas Island NS
# ...

# %%
# 2. Print a heat map of this correlation matrix (hint: use seaborn.heatmap())
print(sns.heatmap(cdd.corr()))
# print(cdd.corr(method = "pearson"))
# Out:
# AxesSubplot(0.125,0.125;0.62x0.755)

# %%
cdd.corr(method = "pearson")
# Out:
#                                 FATALITIES  INJURED / INFECTED  EVACUATED  \
# FATALITIES                        1.000000            0.998728  -0.003530
# INJURED / INFECTED                0.998728            1.000000  -0.003554
# EVACUATED                        -0.003530           -0.003554   1.000000
# ESTIMATED TOTAL COST              0.027839            0.073538   0.660335
# NORMALIZED TOTAL COST             0.031352            0.080907   0.580352
# FEDERAL DFAA PAYMENTS             0.014838            0.311491   0.406679
# PROVINCIAL DFAA PAYMENTS         -0.020317            0.404215   0.083692
# PROVINCIAL DEPARTMENT PAYMENTS   -0.023630           -0.002056   0.212975
# MUNICIPAL COSTS                   0.965880            0.965286   0.514186
# OGD COSTS                         0.417442           -0.036915   0.154761
# INSURANCE PAYMENTS                0.241347            0.456924   0.825937
# NGO PAYMENTS                      0.966678            0.999639   0.838898
# ...

# %% [markdown]
# **Disaster Type** The type of disaster (e.g. flood, earthquake, etc.) that occurred.
#
# **Date of Event** The date a specific event took place.
#
# **Specific Location** The city, town or region where a specific event took place.
#
# **Description of Event** A brief description of a specific event, including pertinent details that may not be captured in other data fields (e.g. amount of precipitation, temperatures, neighbourhoods, etc.)
#
# **Fatalities** The number of people killed due to a specific event.
#
# **Injured/Infected** The number of people injured or infected due to a specific event.
#
# **Evacuees** The number of individuals evacuated by the government of Canada due to a specific event.
#
# **Latitude & Longitude** The exact geographic location of a specific event.
#
# **Province/Territory** The province or territory where a specific event took place.
#
# **Estimated Total Cost** A roll-up of all the costs listed within the financial data fields for a specific event.
#
# **DFAA Payments** The amount, in dollars, paid out by Disaster Financial Assistance Arrangements (Public Safety Canada) due to a specific event.
#
# **Insurance Payments** The amount, in dollars, paid out by insurance companies due to a specific event.
#
# **Provincial/Territorial** Costs/Payments The amount, in dollars, paid out by a Province or Territory due to a specific event.
#
# **Utility Costs/Losses** The amount of people whose utility services (power, water, etc.) were interrupted/affected by a specific event.
#
# **Magnitude** A measure of the size of an earthquake, related to the amount of energy released.
#
# **Other Federal Institution Costs** The amount, in dollars, paid out by other federal institutions.

# %% [markdown]
# # 3. Find 3 pairs of columns, one pair that is highly positively correlated, one for which the correlation is almost zero and one pair that is negatively correlated. In each case write down an explanation why we see this correlation

# %% [markdown]
# # 4. Look up the pairplot function in Seaborn. Use it to plot the pairwise relations between the six columns you selected. Does what you see confirm your ideas? Describe in a comment.

# %% [markdown]
# ## correlation = positive
# FATALITIES & INJURED / INFECTED = 0.998728
#
# The number of people killed due to a specific event and the number of people injured or infected due
# to a specific event are highly correlated. This makes sense because people that were killed were ofcourse injured

# %%
sns.pairplot(data=cdd[["FATALITIES","INJURED / INFECTED"]])

# %% [markdown]
# ## correlation = zero
# FATALITIES & FEDERAL DFAA PAYMENTS = 0.014838
#
# The number of people killed due to a specific event and the amount, in dollars, paid out by
# Disaster Financial Assistance Arrangements (Public Safety Canada) due to a specific event. As there is no
# correlation, this could mean that the payments are not dependent on the number of fatalities, e.g., they will
# keep paying whenever there is a specific event.

# %%
sns.pairplot(data=cdd[["FATALITIES","FEDERAL DFAA PAYMENTS"]])

# %% [markdown]
# ## correlation = negative
# UTILITY - PEOPLE AFFECTED & OGD COSTS = -0.092983
#
# There is no high negative correlation. A negative correlation (although very small) is the amount of people whose utility services (power, water, etc.) were interrupted/affected by a specific event
# and the other governmental costs. As said they are little negatively related so this could mean that if there are less people that are
# affected by a specific event, the less OGD costs there could be.

# %%
sns.pairplot(data=cdd[["UTILITY - PEOPLE AFFECTED","OGD COSTS"]])

# %%
# sns.pairplot(data=cdd[["FATALITIES","INJURED / INFECTED","FEDERAL DFAA PAYMENTS","UTILITY - PEOPLE AFFECTED","OGD COSTS"]])
