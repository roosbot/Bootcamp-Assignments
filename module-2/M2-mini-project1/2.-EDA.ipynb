# %% [markdown]
# # Descriptive Statistics Review
#
# In this second part of the lab, we are going to continue working with the data that we cleaned in the last part.
# Be sure to continue to write clean code and comment your work well!
#
# First, lets import our libraries and the data we saved.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
diamonds = pd.read_csv('./diamonds_clean.csv')
diamonds

# %% [markdown]
# Now that we cleaned our data, we can proceed with some exploratory analysis. We will analyze the features that affect price the most.
#
# Let's start by looking at how the charateristics of a diamond (especially the price, since that's our focus) change based on its color. Remember that you can use the `groupby()` method in pandas.
#
# **Using the `describe()` method, take a look on the dataset paying special attention to the variability. Comment what you see.**

# %%
#your code here
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53932.000000  53932.000000  53932.000000  53932.000000  53932.000000
# mean       0.797879     61.749336     57.457029   3932.136079      5.732007
# std        0.473986      1.432514      2.234064   3988.734835      1.119670
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.750000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z  clarity_number  color_number        z_orig  \
# count  53932.000000  53932.000000    53932.000000  53932.000000  53932.000000
# mean       5.733335      3.539735        3.051101      3.405789      3.540266
# std        1.113960      0.692051        1.647109      1.701165      0.702667
# min       -7.816316      1.070000        0.000000      0.000000      1.070000
# 25%        4.720000      2.910000        2.000000      2.000000      2.910000
# 50%        5.710000      3.530000        3.000000      3.000000      3.530000
# 75%        6.540000      4.040000        4.000000      5.000000      4.040000
# max       10.540000      8.060000        7.000000      6.000000     31.800000
#
#          cut_number
# count  53932.000000
# mean       2.904194
# std        1.116526
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000

# %%
"""
I still need to change the negative y values. 
Next to that the numbers seem good and ready for analysis.
"""

# %% [markdown]
# Let's proceed to check each feature separately.
#
# **Before starting, which features do you think that will affect the price most and why? You will contrast your hypotheses with your results.**

# %%
"""
Hypothesis:
I believe the price will be affected by the clarity. The more clear the diamond,
the more beautiful and more rare. The cut is important because the better 
the cut, the higher the diamond price. Also the color affects the price
because the better the color, the higher the price.
"""

# %% [markdown]
# ## 1. The `color` column
# First, let's look at the color column.
#
# **For each different color, find the mean of each column. You should have a matrix with every color as rows and the columns `carat`, `clarity`, etc as columns.**

# %%
#your code here
## Diamond colour, from J (worst) to D (best)
diamonds[["color","carat","clarity_number","depth","table","price","x","y","z"]].groupby("color").mean()

# https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html
# Out:
#           carat  clarity_number      depth      table        price         x  \
# color
# D      0.657715        2.691025  61.698066  57.404355  3168.106436  5.417851
# E      0.657867        2.969889  61.662090  57.491201  3076.752475  5.411580
# F      0.736509        3.134605  61.694087  57.433148  3725.091938  5.616727
# G      0.771088        3.463419  61.757449  57.288060  3998.145173  5.678549
# H      0.911627        2.933871  61.836557  57.518176  4484.958805  5.984776
# I      1.026927        2.964035  61.846385  57.577278  5091.874954  6.222826
# J      1.162137        2.776353  61.887215  57.812393  5323.818020  6.519338
#
#               y         z
# color
# D      5.421928  3.343320
# E      5.415275  3.337767
# F      5.620529  3.465938
# G      5.681198  3.507966
# H      5.978220  3.699147
# I      6.222730  3.846368
# J      6.518105  4.033251

# %% [markdown]
# **What do you see? Pay special attention to the relationship between price and color.**

# %%
"""
From D to J, the carat is getting higher. So the heavier the diamond, the worse the color.
From D to J, the clarity is appr. exqual, but the highest for G. So it doesn't mean the more clear the diamond, the better the color

From D to J, the depth is staying appr. the same.
From D to J, the table is staying appr. the same.
From D to J, the price is getting higher. This doesn't make sense to me. The better the color means the lower the price?

From D to J, the x is slowly getting higher.
From D to J, the y is slowly getting higher.
From D to J, the x is slowly getting higher.
"""

# %% [markdown]
# Let's go further into the color feature. We will plot the frequency distribution of the diamonds color in our dataset.
#
# **Plot the distribution and analyze it. Remember that you can use the pandas `plot()` method.**

# %%
#your code here
diamonds['color'].value_counts().plot(kind='bar')

#https://stackoverflow.com/questions/31029560/plotting-categorical-data-with-pandas-and-matplotlib

# %%
"""
## Diamond colour, from J (worst) to D (best)

The distribution shows that G and E have the highest frequency.
I and J are the least common. This means that there are not a lot diamonds with a bad diamond color


"""

# %% [markdown]
# ## 2.The `carat` column

# %% [markdown]
# Let's check the `carat` (weight), since this could also be a potential factor for price change.
#
# **Find the mean of each column for each value of `carat` using the `groupby` method. Then comment your results.**

# %%
#your code here

## Color
## Diamond colour, from J (worst) to D (best)
## From 0 to 6

## Clarity:
## (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
## 0 to 6

diamonds[["color_number","clarity_number","carat","depth","table","price","x","y","z"]].groupby("carat").mean()

# https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html
# Out:
#        color_number  clarity_number      depth      table         price  \
# carat
# 0.20       5.166667        2.833333  61.100000  59.333333    365.166667
# 0.21       5.444444        2.666667  60.511111  58.444444    380.222222
# 0.22       4.800000        2.600000  61.620000  60.400000    391.400000
# 0.23       4.518771        4.901024  61.426621  58.034130    486.143345
# 0.24       4.185039        4.972441  61.599213  57.488189    505.185039
# ...             ...             ...        ...        ...           ...
# 4.00       1.000000        0.000000  63.300000  58.000000  15984.000000
# 4.01       0.500000        0.000000  61.750000  61.500000  15223.000000
# 4.13       2.000000        0.000000  64.800000  61.000000  17329.000000
# 4.50       0.000000        0.000000  65.800000  58.000000  18531.000000
# 5.01       0.000000        0.000000  65.500000  59.000000  18018.000000
#
#                x          y         z
# carat
# 0.20    3.786667   3.753333  2.303333
# 0.21    3.874444   3.837778  2.332222
# 0.22    3.898000   3.848000  2.386000
# 0.23    3.946382   3.973379  2.431468
# 0.24    3.990157   4.019331  2.465591
# ...          ...        ...       ...
# 4.00   10.010000   9.940000  6.310000
# 4.01   10.080000  10.020000  6.205000
# 4.13   10.000000   9.850000  6.430000
# 4.50   10.230000  10.160000  6.720000
# 5.01   10.740000  10.540000  6.980000
#
# [273 rows x 8 columns]

# %%
"""
The higher the carat weight, the lower the color_number. Meaning the best color diamonds are the lightest.
The higher the carat weight, the lower the clarity_number. The lighter the diamond, the clearer the diamond.
For carat weight, the depth is appr. equal but the highest in the heaviest carat weights.
For carat weight, the depth is appr. equal.
The higher the carat weight, the higher the price. Meaning that lighter diamonds are cheaper.
The higher the carat weight, the higher x, y and z.
"""

# %% [markdown]
# **Plot a histogram of the `carat` column by using the `plot` method (see the docs to find an easy way to do so). What is happening?**

# %%
#your code here
# diamonds["carat"].value_counts().plot(kind="bar")

diamonds[["carat"]].plot(kind='hist',bins=[0,.2,.4,.6,.8,1])
plt.show()

# https://matplotlib.org/api/_as_gen/matplotlib.pyplot.html#module-matplotlib.pyplot
# https://queirozf.com/entries/pandas-dataframe-plot-examples-with-matplotlib-pyplot

# %% [markdown]
# # 3. The `table` and `clarity` column
# Finally, let's check the `table`.
#
# **Find the mean of each column for each value of `table` using the `groupby` method. Then comment your results.**

# %%
#your code here
## Table = Width of top of diamond relative to widest point

## Color
## Diamond colour, from J (worst) to D (best)
## From 0 to 6

## Clarity:
## (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
## 0 to 7

diamonds[["color_number","clarity_number","carat","depth","table","price","x","y","z"]].groupby("table").mean()

# https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html
# Out:
#        color_number  clarity_number   carat  depth    price      x      y  \
# table
# 43.0            1.0            4.00  1.0400  62.90   4997.0  6.450  6.410
# 44.0            5.0            4.00  0.2900  62.80    474.0  4.200  4.240
# 49.0            3.0            3.00  0.6500  64.25   2290.5  5.355  5.320
# 50.0            3.0            2.00  1.5100  61.50   8995.5  7.380  7.295
# 50.1            2.0            1.00  0.9400  66.00   3353.0  6.130  6.170
# ...             ...             ...     ...    ...      ...    ...    ...
# 71.0            3.0            2.00  0.6800  58.00   1633.0  5.850  5.700
# 73.0            4.5            3.25  0.6025  68.90   2406.5  5.520  5.465
# 76.0            3.0            2.00  0.7900  65.30   2362.0  5.520  5.130
# 79.0            4.0            1.00  0.8100  68.80   2301.0  5.260  5.200
# 95.0            4.0            2.00  2.0100  58.60  13387.0  8.320  8.310
#
#            z
# table
# 43.0   4.040
# 44.0   2.650
# 49.0   3.425
# 50.0   4.510
# 50.1   4.060
# ...      ...
# 71.0   3.350
# 73.0   3.745
# 76.0   3.350
# 79.0   3.580
# 95.0   4.870
#
# [127 rows x 8 columns]

# %%
"""
The higher table, the higher the price. Meaning the wider the diamond, the more expensive the diamond.

"""

# %% [markdown]
# **Finally, do the same with the `clarity` column.**

# %%
#your code here
## (I1 (worst), SI2, SI1, VS2, VS1, VVS2, VVS1, IF (best))
## 0 to 7

diamonds[["color_number","clarity","carat","depth","table","price","x","y","z"]].groupby("clarity").mean()

# https://pandas.pydata.org/docs/getting_started/intro_tutorials/06_calculate_statistics.html
# Out:
#          color_number     carat      depth      table        price         x  \
# clarity
# I1           2.968961  1.283846  62.734278  58.303779  3924.168691  6.761093
# IF           3.101676  0.505123  61.510615  56.507207  2864.839106  4.968402
# SI1          3.448450  0.850482  61.853042  57.662541  3996.001148  5.888383
# SI2          3.469967  1.077602  61.771567  57.926823  5062.267356  6.404157
# VS1          3.161812  0.727108  61.667968  57.313966  3839.144308  5.572860
# VS2          3.494370  0.763850  61.724249  57.418040  3924.166204  5.658633
# VVS1         3.350848  0.503131  61.624521  56.883881  2519.512315  4.961721
# VVS2         3.569483  0.596202  61.663778  57.024990  3283.737071  5.218454
#
#                 y         z
# clarity
# I1       6.709379  4.224683
# IF       4.989827  3.061659
# SI1      5.888256  3.640636
# SI2      6.392630  3.952642
# VS1      5.578009  3.437924
# VS2      5.659782  3.492788
# VVS1     4.976437  3.062132
# VVS2     5.232118  3.221465

# %%
"""
I1 is the worst clarity and has the highest carat weight
SI2 is the second worst clarity and has the highest mean price. 

IF and VVS1 are the clearest diamonds and have the lowest price.

"""

# %%
diamonds["clarity_number"].value_counts()
# Out:
# 2    13065
# 3    12256
# 1     9190
# 4     8170
# 5     5066
# 6     3654
# 7     1790
# 0      741
# Name: clarity_number, dtype: int64

# %%
# Make number of cut
## (Fair, Good, Very Good, Premium, Ideal)
## 0 to 4
diamonds['cut_number'] = diamonds['cut'].replace({"Ideal":4, "Premium":3, "Very Good":2,"Good":1,"Fair":0})
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53927   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53928   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53929   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53930   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53931   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
#        clarity_number  color_number  z_orig  cut_number
# 0                   1             5    2.43           4
# 1                   2             5    2.31           3
# 2                   4             5    2.31           1
# 3                   3             1    2.63           3
# 4                   1             0    2.75           1
# ...               ...           ...     ...         ...
# 53927               2             6    3.50           4
# 53928               2             6    3.61           1
# 53929               2             6    3.56           2
# 53930               1             2    3.74           3
# 53931               1             6    3.64           4
#
# [53932 rows x 14 columns]

# %%
# Cut 
diamonds[["cut_number","color_number","clarity","carat","depth","table","price","x","y","z"]].groupby("cut_number").mean()

# diamonds["cut_number"].value_counts()
# Out:
#             color_number     carat      depth      table        price  \
# cut_number
# 0               3.148539  1.046078  64.045743  59.048850  4357.500932
# 1               3.426591  0.849241  62.365171  58.694107  3929.598083
# 2               3.433573  0.806365  61.818152  57.956560  3981.664101
# 3               3.302560  0.891834  61.264501  58.746058  4582.477192
# 4               3.470741  0.702780  61.709383  55.951756  3457.038981
#
#                    x         y         z
# cut_number
# 0           6.250777  6.186495  3.985245
# 1           5.841166  5.853130  3.643071
# 2           5.741171  5.770503  3.557726
# 3           5.974754  5.940902  3.650557
# 4           5.507962  5.518578  3.401952

# %% [markdown]
# **After looking at your results, which features do you think will affect price the most now? Regarding your hypotheses, do they match your final results? Provide a small overview.**

# %%
"""

--
Hypothesis:
I believe the price will be affected by the clarity. The more clear the diamond,
the more beautiful and more rare. The cut is important because the better 
the cut, the higher the diamond price. Also the color affects the price
because the better the color, the higher the price.
--
Results:
The better the color means the lower the price.
The lighter the diamond, the clearer the diamond.
Meaning the best color diamonds are the lightest.
Meaning that lighter diamonds are cheaper.
Meaning the wider the diamond, the more expensive the diamond.
IF and VVS1 are the clearest diamonds and have the lowest price.
--
Conclusion:
I thought the clearer the diamond, the rarer. The rarest diamond is the most unclear one. However, next to that the clearest diamonds are more rare.
I thought the better the color, the higher the price. However, it seems that the better the color, the lower the price!
I thought the better the cut, the higher the diamond price. However, there doesn't seem to be a big difference between cut and price.

I'd buy:
- the best color (Higher number)
- the lowest price
- the lightest diamond
- the least wide diamond (Low table number)

Color D/E (best color), lowest price

"""

# %%
mydiamond = diamonds[(diamonds["color"] == "D") &
                     (diamonds["price"] < 400) &
                     (diamonds["carat"] < 0.25) &
                     (diamonds["table"] < 60) &
                     (diamonds["cut"] == "Ideal")
                    ]
mydiamond
# Out:
#        carat    cut color clarity  depth  table  price     x     y     z  \
# 31591    0.2  Ideal     D     VS2   61.5   57.0    367  3.81  3.77  2.33
#
#        clarity_number  color_number  z_orig  cut_number
# 31591               3             6    2.33           4

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53932.000000  53932.000000  53932.000000  53932.000000  53932.000000
# mean       0.797879     61.749336     57.457029   3932.136079      5.732007
# std        0.473986      1.432514      2.234064   3988.734835      1.119670
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.750000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z  clarity_number  color_number        z_orig  \
# count  53932.000000  53932.000000    53932.000000  53932.000000  53932.000000
# mean       5.733335      3.539735        3.051101      3.405789      3.540266
# std        1.113960      0.692051        1.647109      1.701165      0.702667
# min       -7.816316      1.070000        0.000000      0.000000      1.070000
# 25%        4.720000      2.910000        2.000000      2.000000      2.910000
# 50%        5.710000      3.530000        3.000000      3.000000      3.530000
# 75%        6.540000      4.040000        4.000000      5.000000      4.040000
# max       10.540000      8.060000        7.000000      6.000000     31.800000
#
#          cut_number
# count  53932.000000
# mean       2.904194
# std        1.116526
# min        0.000000
# 25%        2.000000
# 50%        3.000000
# 75%        4.000000
# max        4.000000

# %% [markdown]
# # Bonus: taking a deeper look with plots and correlations
#
# To take deeper look, we will use the `pairplot` method of `seaborn` library. This method plots a scatterplot for each pair of features and in the diagonal the distribution of the feature.
#
# So if you have many features it will take a while, be careful!

# %%
#Run this code
import seaborn as sns
sns.pairplot(diamonds, diag_kind = 'kde', plot_kws = {'alpha': 0.6, 's': 80, 'edgecolor': 'k'})

# %% [markdown]
# **What do you see here? What relationships between variables are the most interesting?**

# %%
#your thoughts here

# %% [markdown]
# Now we will see a correlation matrix with a plot. As you know a higher correlation means that the feature could be an effect (**but is not for sure**) for the changes on the price.
#
# We will see this with a matrix with colors. A lighter color means greater correlation.
#
# This is done with the `seaborn` library as well.

# %%
#Run this code
plt.figure(figsize=(20, 20))
p = sns.heatmap(diamonds.corr(), annot=True, square=True)

# %% [markdown]
# **What do you see here? Regarding the results before, does it fit with them?**

# %%
#your thoughts here

# %% [markdown]
# Finally, we will calculate the linear regression between the price and the weight. This will be done first by plotting it with the `seaborn` library and then calculating the error with the `scipy` library.

# %%
#Run this code
plt.figure(figsize=(10, 10))
sns.regplot(diamonds.carat, diamonds.price, scatter=True)

# %%
#Run this code
from scipy import stats
slope, intercept, r_value, p_value, std_err = stats.linregress(diamonds.carat, diamonds.price)
r2 = r_value ** 2
r2

# %% [markdown]
# **What do you think?**

# %%
#your thoughts here

# %% [markdown]
# **Would you do any other checks on other features? Do you have any comments regarding `carat`?**

# %%
#your thoughts here

# %% [markdown]
# **Conlcusion**

# %% [markdown]
# **From our dataset** we can conclude that although `color` and `clarity` have a classification, and thus an assigned importance or weight, they do not influence the monetary value of a diamond in determining way. While it is true that different colors or clarities may have different prices, upon closer examination those variations in price seem to be linked to `carat` (weight) and its `dimensions`. In our analysis, the key factor to determining a diamond's value was placed solely in the aforementioned features, since we can see in our correlation coefficients and in the coefficient of determination that these features are closely related.
