# %% [markdown]
# Resources:
#
# https://pypi.org/project/advertools/
# https://github.com/eliasdabbas/advertools/issues/39
# https://www.kaggle.com/eliasdabbas/coffee-and-cafe-search-results-on-google/metadata

# %% [markdown]
# 1. Study documentation at https://advertools.readthedocs.io/en/master/advertools.serp.html
# 2. Create Search engine ID (CX) at https://cse.google.com/cse
# 3. Create Custom Search API key at https://console.developers.google.com/apis
# 4. Add more parameters https://advertools.readthedocs.io/en/master/_modules/advertools/serp.html

# %%
import advertools as adv

# %%
data = adv.serp_goog(q=["yerba mate"], cx="003868774165129823113:fhn9_b5mbsk", key="AIzaSyD30G9QC5zQVuzg-DHqCOebttpu5s7dwBA",gl="nl",cr=["countryNL"])
data
# Out:
# INFO:root:Requesting: q=yerba mate, cx=003868774165129823113:fhn9_b5mbsk, key=AIzaSyD30G9QC5zQVuzg-DHqCOebttpu5s7dwBA, cr=countryNL, gl=nl
#           cr  gl searchTerms  rank  \
# 0  countryNL  nl  yerba mate     1
# 1  countryNL  nl  yerba mate     2
# 2  countryNL  nl  yerba mate     3
# 3  countryNL  nl  yerba mate     4
#
#                                                title  \
# 0  SEO: 127% groei van organisch zoekverkeer in 1...
# 1  WhatsApp incorpora el emoji del mate a partir ...
# 2        Steviolglycosiden: ESstevia tablets 200 pcs
# 3  US20090227673A1 - Method and Composition for t...
#
#                                              snippet           displayLink  \
# 0  16 okt 2019 ... On 13 september 2018 publiceer...  feedproxy.google.com
# 1  22 Ene 2019 ... Un gráfico que representa a la...       news.google.com
# 2  Other Stevia products · Literature · Stevia & ...  feedproxy.google.com
# 3  Notable sources of polyphenols include berries...        www.google.com
# ...

# %%
data.describe()
# Out:
#            rank  count  searchTime  startIndex
# count  4.000000    4.0    4.000000         4.0
# mean   2.500000    4.0    0.445514         1.0
# std    1.290994    0.0    0.000000         0.0
# min    1.000000    4.0    0.445514         1.0
# 25%    1.750000    4.0    0.445514         1.0
# 50%    2.500000    4.0    0.445514         1.0
# 75%    3.250000    4.0    0.445514         1.0
# max    4.000000    4.0    0.445514         1.0

# %%
list(data.columns)
# Out:
# ['cr',
#  'gl',
#  'searchTerms',
#  'rank',
#  'title',
#  'snippet',
#  'displayLink',
#  'link',
#  'queryTime',
#  'totalResults',
#  'cacheId',
#  'count',
#  'cseName',
#  'cx',
#  'formattedSearchTime',
#  'formattedTotalResults',
#  'formattedUrl',
#  'htmlFormattedUrl',
#  'htmlSnippet',
#  'htmlTitle',
#  'inputEncoding',
#  'kind',
#  'outputEncoding',
#  'pagemap',
#  'safe',
#  'searchTime',
#  'startIndex',
#  'cse_thumbnail',
#  'metatags',
#  'cse_image',
#  'scholarlyarticle',
#  'og:image',
#  'article:published_time',
#  'og:image:width',
#  'twitter:card',
#  'theme-color',
#  'og:site_name',
#  'msapplication-tileimage',
#  'og:description',
#  'twitter:creator',
#  'article:publisher',
#  'og:image:secure_url',
#  'twitter:image',
#  'twitter:site',
#  'article:modified_time',
#  'msapplication-tilecolor',
#  'og:type',
#  'article:section',
#  'twitter:title',
#  'og:title',
#  'og:image:height',
#  'og:updated_time',
#  'article:tag',
#  'fb:app_id',
# ...

# %%
import pandas as pd
import pyreadstat

# %%
data, meta = pyreadstat.read_sav("./data/GEM 2016 APS Global - Individual Level Data.sav")

# Source: https://www.marsja.se/how-to-read-write-spss-files-in-python-pandas/
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-7-890b0e310ae6> in <module>
# ----> 1 data, meta = pyreadstat.read_sav("./data/GEM 2016 APS Global - Individual Level Data.sav")
#
# pyreadstat/pyreadstat.pyx in pyreadstat.pyreadstat.read_sav()
#
# pyreadstat/_readstat_parser.pyx in pyreadstat._readstat_parser.run_conversion()
#
# pyreadstat/_readstat_parser.pyx in pyreadstat._readstat_parser.handle_value()
#
# pyreadstat/_readstat_parser.pyx in pyreadstat._readstat_parser.convert_readstat_to_python_value()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc3 in position 69: unexpected end of data

# %%
from savReaderWriter import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-40140e26fc62> in <module>
# ----> 1 from savReaderWriter import *
#
# ModuleNotFoundError: No module named 'savReaderWriter'

# %%
rawdata = []
with SavReader("./data/GEM 2016 APS Global - Individual Level Data.sav", ioUtf8=True) as reader:
    for record in reader:
        try:
            rawdata.append(record)
        except UnicodeDecodeError:
            r = record.decode('latin-1')
            rawdata.append(r.encode('utf-8'))                
data = pd.DataFrame(raw_data_list)
data = data.rename(columns=data.loc[0]).iloc[1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-75feb55e4ad6> in <module>
#       1 rawdata = []
# ----> 2 with SavReader("./data/GEM 2016 APS Global - Individual Level Data.sav", ioUtf8=True) as reader:
#       3     for record in reader:
#       4         try:
#       5             rawdata.append(record)
#
# NameError: name 'SavReader' is not defined

# %%
data.head(5)

# %%
data = pd.read_spss("./data/GEM 2016 APS Global - Individual Level Data.sav",encoding="latin1")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-1e93fbbe0638> in <module>
#       1 import pandas as pd
# ----> 2 data = pd.read_spss("./data/GEM 2016 APS Global - Individual Level Data.sav",encoding="latin1")
#
# TypeError: read_spss() got an unexpected keyword argument 'encoding'
