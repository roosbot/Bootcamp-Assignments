# %% [markdown]
# # Understanding Over & Underfitting
# ## Predicting Boston Housing Prices

# %% [markdown]
# ## Getting Started
# In this project, you will use the Boston Housing Prices dataset to build several models to predict the prices of homes with particular qualities from the suburbs of Boston, MA.
# We will build models with several different parameters, which will change the goodness of fit for each.

# %% [markdown]
# ---
# ## Data Exploration
# Since we want to predict the value of houses, the **target variable**, `'MEDV'`, will be the variable we seek to predict.

# %% [markdown]
# ### Import and explore the data. Clean the data for outliers and missing values.

# %%
# Import libraries
import pandas as pd
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("../data/boston_data.csv")
data.head(5)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad    tax  \
# 0  0.15876   0.0  10.81   0.0  0.413  5.961  17.5  5.2873  4.0  305.0
# 1  0.10328  25.0   5.13   0.0  0.453  5.927  47.2  6.9320  8.0  284.0
# 2  0.34940   0.0   9.90   0.0  0.544  5.972  76.7  3.1025  4.0  304.0
# 3  2.73397   0.0  19.58   0.0  0.871  5.597  94.9  1.5257  5.0  403.0
# 4  0.04337  21.0   5.64   0.0  0.439  6.115  63.0  6.8147  4.0  243.0
#
#    ptratio   black  lstat  medv
# 0     19.2  376.94   9.88  21.7
# 1     19.7  396.90   9.22  19.6
# 2     18.4  396.24   9.97  20.3
# 3     14.7  351.85  21.45  15.4
# 4     16.8  393.97   9.43  20.5

# %% [markdown]
# ### Next, we want to explore the data. Pick several varibables you think will be ost correlated with the prices of homes in Boston, and create plots that show the data dispersion as well as the regression line of best fit.

# %% [markdown]
# **Data Description from Kaggle**
#
# **crim** - per capita crime rate by town.
#
# **zn** - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# **indus** - proportion of non-retail business acres per town.
#
# **chas** - Charles River dummy variable (= 1 if tract bounds river; 0 otherwise).
#
# **nox** - nitrogen oxides concentration (parts per 10 million).
#
# **rm** - average number of rooms per dwelling.
#
# **age** - proportion of owner-occupied units built prior to 1940.
#
# **dis** - weighted mean of distances to five Boston employment centres.
#
# **rad** - index of accessibility to radial highways.
#
# **tax** - full-value property-tax rate per 10,000.
#
# **ptratio** - pupil-teacher ratio by town.
#
# **black** - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town.
#
# **lstat** - lower status of the population (percent).
#
# **medv** - median value of owner-occupied homes in $1000s.

# %%
# Lstat & Medv (-0.7)
sns.lmplot(x="lstat", y="medv", data=data)

"""
lstat - lower status of the population (percent).
medv - median value of owner-occupied homes in $1000s.
"""

# %% [markdown]
# ### What do these plots tell you about the relationships between these variables and the prices of homes in Boston? Are these the relationships you expected to see in these variables?

# %%
"""
For example lstat and medv seem to negatively correlate. Meaning the lower the percentage of lower status of 
the population, the higher the median value of occupied homes. This is expected because people of higher status 
often have higher income and therefore can buy more expensive houses.
"""

# %% [markdown]
# ### Make a heatmap of the remaining variables. Are there any variables that you did not consider that have very high correlations? What are they?

# %%
# Check for correlations
data.corr().style.background_gradient(cmap="coolwarm")

# sns.pairplot(data)
# Out:
# <style  type="text/css" >
#     #T_4ffce8fe_bb79_11ea_a0a6_406c8f3bc41crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_4ffce8fe_bb79_11ea_a0a6_406c8f3bc41crow0_col1 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_4ffce8fe_bb79_11ea_a0a6_406c8f3bc41crow0_col2 {
#             background-color:  #f6bda2;
#             color:  #000000;
#         }    #T_4ffce8fe_bb79_11ea_a0a6_406c8f3bc41crow0_col3 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_4ffce8fe_bb79_11ea_a0a6_406c8f3bc41crow0_col4 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_4ffce8fe_bb79_11ea_a0a6_406c8f3bc41crow0_col5 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_4ffce8fe_bb79_11ea_a0a6_406c8f3bc41crow0_col6 {
#             background-color:  #f4c5ad;
#             color:  #000000;
# ...

# %%
# Tax & Rad (0.9)
sns.lmplot(x="tax", y="rad", data=data)

"""
rad - index of accessibility to radial highways.
tax - full-value property-tax rate per 10,000.

I did not expect this to be so highly correlated, because I didn't think that accessibility was related to tax.

"""

# %% [markdown]
# ### Calculate Statistics
# Calculate descriptive statistics for housing price. Include the minimum, maximum, mean, median, and standard deviation.

# %%
# Your code here
data.describe()
# Out:
#              crim          zn       indus        chas         nox         rm  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.00000
# mean     3.730912   10.509901   11.189901    0.069307    0.556710    6.30145
# std      8.943922   22.053733    6.814909    0.254290    0.117321    0.67583
# min      0.006320    0.000000    0.460000    0.000000    0.392000    3.56100
# 25%      0.082382    0.000000    5.190000    0.000000    0.453000    5.90275
# 50%      0.253715    0.000000    9.795000    0.000000    0.538000    6.23050
# 75%      4.053158   12.500000   18.100000    0.000000    0.631000    6.62925
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.78000
#
#               age         dis         rad         tax     ptratio       black  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    68.601733    3.799666    9.836634  411.688119   18.444554  355.068243
# ...

# %% [markdown]
# ----
#
# ## Developing a Model

# %% [markdown]
# ### Implementation: Define a Performance Metric
# What is the performance meteric with which you will determine the performance of your model? Create a function that calculates this performance metric, and then returns the score.

# %%
from sklearn.metrics import r2_score

def performance_metric(y_true, y_predict):
    """ Calculates and returns the performance score between 
        true and predicted values based on the metric chosen. """
    # Your code here:
    score = r2_score(y_true, y_predict)
    return score

# %% [markdown]
# ### Implementation: Shuffle and Split Data
# Split the data into the testing and training datasets. Shuffle the data as well to remove any bias in selecting the traing and test.

# %%
# Import library
from sklearn.model_selection import train_test_split

# Define independent and dependent variables
data_x = data[data.columns.difference(["medv"])]
data_y = data["medv"]

# Split data in test and train
X_train, X_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.2, shuffle=True)

# %% [markdown]
# ----
#
# ## Analyzing Model Performance
# Next, we are going to build a Random Forest Regressor, and test its performance with several different parameter settings.

# %% [markdown]
# ### Learning Curves
# Lets build the different models. Set the max_depth parameter to 2, 4, 6, 8, and 10 respectively.

# %%
# Import model
from sklearn.ensemble import RandomForestRegressor

# Instantiate model with different depth of the tree
max_depth = [2,4,6,8,10]
test = []
models = []
scores = []

for depth in max_depth:
    rfr = RandomForestRegressor(max_depth=depth)
    rfr = rfr.fit(X_train, y_train)
    y_pred = rfr.predict(X_test)
    score = performance_metric(y_test, y_pred)
    
    models.append(rfr)
    scores.append(score)
    
#     plt.boxplot(score, labels=rfr)

# print(scores)

# %% [markdown]
# Now, plot the score for each tree on the training set and on the testing set.

# %%
# Produce a plot with the score for the testing and training
# for the different max depths

from sklearn.model_selection import learning_curve

learning_curves(estimator=rfr, X=X_train, y=, train_sizes= max_depth)

# %%
# train_sizes = [1, 25, 50, 100, 200, 390] # 390 is 80% of shape(X)

# from sklearn.model_selection import learning_curve
# def learning_curves(estimator, X, y, train_sizes, cv):
#     train_sizes, train_scores, validation_scores = learning_curve(
#                                                  estimator, X, y, train_sizes = train_sizes,
#                                                  cv = cv, scoring = 'neg_mean_squared_error')
#     #print('Training scores:\n\n', train_scores)
#     #print('\n', '-' * 70) # separator to make the output easy to read
#     #print('\nValidation scores:\n\n', validation_scores)
#     train_scores_mean = -train_scores.mean(axis = 1)
#     print(train_scores_mean)
#     validation_scores_mean = -validation_scores.mean(axis = 1)
#     print(validation_scores_mean)

#     plt.plot(train_sizes, train_scores_mean, label = 'Training error')
#     plt.plot(train_sizes, validation_scores_mean, label = 'Validation error')

#     plt.ylabel('MSE', fontsize = 14)
#     plt.xlabel('Training set size', fontsize = 14)
#     title = 'Learning curves for a ' + str(estimator).split('(')[0] + ' model'
#     plt.title(title, fontsize = 18, y = 1.03)
#     plt.legend()
#     plt.ylim(0,40)
    
# # Derived from: https://stackoverflow.com/questions/53596459/learning-curve-sklearn

# %% [markdown]
# What do these results tell you about the effect of the depth of the trees on the performance of the model?

# %%
"""
The more trees you add, the more specific you are, therefore it can lead to overfitting. However, it does handles outliers well.
"""

# %% [markdown]
# ### Bias-Variance Tradeoff
# When the model is trained with a maximum depth of 1, does the model suffer from high bias or from high variance? How about when the model is trained with a maximum depth of 10?

# %%
"""
When the model is trained with a maximum depth of 1, does the model suffer from high bias or from high variance?
--> High bias, the small gap indicates that it is unable to fit the model well
How about when the model is trained with a maximum depth of 10?
--> High variance, the large gap indicates that it is unable to validate the model.
"""
# Resource: https://www.ritchieng.com/machine-learning-project-boston-home-prices/
# Out:
# ''

# %% [markdown]
# ### Best-Guess Optimal Model
# What is the max_depth parameter that you think would optimize the model? Run your model and explain its performance.

# %%
"""
Depth of 4
"""

rfr = RandomForestRegressor(max_depth=4)
rfr = rfr.fit(X_train, y_train)
y_pred = rfr.predict(X_test)
score = performance_metric(y_test, y_pred)

print(score)
# Out:
# 0.8408816694022704

# %% [markdown]
# ### Applicability
# *In a few sentences, discuss whether the constructed model should or should not be used in a real-world setting.*
# **Hint:** Some questions to answering:
# - *How relevant today is data that was collected from 1978?*
# - *Are the features present in the data sufficient to describe a home?*
# - *Is the model robust enough to make consistent predictions?*
# - *Would data collected in an urban city like Boston be applicable in a rural city?*

# %%
"""
How relevant today is data that was collected from 1978?
--> Not so relevant as the city and demographics may have changed

Are the features present in the data sufficient to describe a home?
--> No there could be more features added as to see what defines a home

Would data collected in an urban city like Boston be applicable in a rural city?
--> No, because then you look at different types of features, as crime rates and public transport are completely different there.

"""

# %%
data.columns
# Out:
# Index(['crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax',
#        'ptratio', 'black', 'lstat', 'medv'],
#       dtype='object')
